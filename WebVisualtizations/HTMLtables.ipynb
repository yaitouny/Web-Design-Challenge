# %%
import pandas as pd

# %%
import datetime

# %%
data_path = "Resources/City_Data.csv"

# %%
data = pd.read_csv(data_path, index_col=0)
data
# Out:
#              Cities    Lat     Lng  Max Temp  Humidity  Wind Speed  \
# 0           rikitea -23.12 -134.97     75.56        79       18.30
# 1       port alfred -33.59   26.89     55.99        85        1.01
# 2            albany  42.60  -73.97     86.00        31        2.68
# 3             vaini -21.20 -175.20     69.80        83       11.41
# 4        dzerzhinsk  56.24   43.46     66.20        88        6.71
# ..              ...    ...     ...       ...       ...         ...
# 508        la rioja  42.25   -2.50     66.20        52        5.82
# 509  severo-kurilsk  50.68  156.12     42.48        90        6.78
# 510            goya -29.14  -59.26     81.46        50       15.32
# 511        skjervoy  70.03   20.97     55.40        66        4.70
# 512         batagay  67.63  134.63     63.99        49        4.50
#
#      Cloudiness Country        Date
# 0            55      PF  1592417809
# 1             0      ZA  1592417810
# 2             0      US  1592417707
# ...

# %%
data.Date = data.Date.apply(lambda x: datetime.datetime.fromtimestamp(x).strftime("%m/%d/%Y"))

# %%
print(data.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cities</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Wind Speed</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>rikitea</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>75.56</td>
#       <td>79</td>
#       <td>18.30</td>
#       <td>55</td>
#       <td>PF</td>
#       <td>06/17/2020</td>
#     </tr>
#     <tr>
#       <td>port alfred</td>
#       <td>-33.59</td>
#       <td>26.89</td>
#       <td>55.99</td>
#       <td>85</td>
#       <td>1.01</td>
#       <td>0</td>
#       <td>ZA</td>
#       <td>06/17/2020</td>
#     </tr>
#     <tr>
#       <td>albany</td>
#       <td>42.60</td>
#       <td>-73.97</td>
#       <td>86.00</td>
#       <td>31</td>
#       <td>2.68</td>
#       <td>0</td>
#       <td>US</td>
# ...
